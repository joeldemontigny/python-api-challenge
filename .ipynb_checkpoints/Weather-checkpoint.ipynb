# %%
# Dependencies and Setup
import json
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy
print (weather_api_key)
# Out:
# d06e88c44960e99e39303205757d5e77

# %% [markdown]
# # Generate the Cities List by Using the citipy Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 606

# %% [markdown]
# # Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?units=imperial&appid=" + weather_api_key

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | yellowknife
# Processing Record 2 of Set 1 | hasaki
# Processing Record 3 of Set 1 | fale old settlement
# Processing Record 4 of Set 1 | prince rupert
# Processing Record 5 of Set 1 | utrik
# Processing Record 6 of Set 1 | mournies
# Processing Record 7 of Set 1 | blackmans bay
# Processing Record 8 of Set 1 | hermanus
# Processing Record 9 of Set 1 | port-aux-francais
# Processing Record 10 of Set 1 | fortaleza
# Processing Record 11 of Set 1 | talnakh
# Processing Record 12 of Set 1 | saipan
# Processing Record 13 of Set 1 | isafjordur
# Processing Record 14 of Set 1 | callao
# Processing Record 15 of Set 1 | nantucket
# Processing Record 16 of Set 1 | hithadhoo
# Processing Record 17 of Set 1 | bontang
# Processing Record 18 of Set 1 | invercargill
# Processing Record 19 of Set 1 | georgetown
# Processing Record 20 of Set 1 | dunbar
# Processing Record 21 of Set 1 | solnechnyy
# Processing Record 22 of Set 1 | bageshwar
# Processing Record 23 of Set 1 | grytviken
# Processing Record 24 of Set 1 | bredasdorp
# Processing Record 25 of Set 1 | aasiaat
# Processing Record 26 of Set 1 | minas de marcona
# Processing Record 27 of Set 1 | vorgashor
# Processing Record 28 of Set 1 | sao tome
# Processing Record 29 of Set 1 | hami
# Processing Record 30 of Set 1 | east london
# Processing Record 31 of Set 1 | benghazi
# Processing Record 32 of Set 1 | javea
# Processing Record 33 of Set 1 | sisimiut
# Processing Record 34 of Set 1 | adamstown
# City not found. Skipping...
# Processing Record 35 of Set 1 | sawakin
# Processing Record 36 of Set 1 | lebu
# Processing Record 37 of Set 1 | ilulissat
# Processing Record 38 of Set 1 | tiksi
# Processing Record 39 of Set 1 | thompson
# Processing Record 40 of Set 1 | pangoa
# Processing Record 41 of Set 1 | bam
# Processing Record 42 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 43 of Set 1 | bethel
# Processing Record 44 of Set 1 | koani
# Processing Record 45 of Set 1 | papatowai
# Processing Record 46 of Set 1 | waitangi
# Processing Record 47 of Set 1 | canon city
# Processing Record 48 of Set 1 | kavieng
# Processing Record 49 of Set 1 | nguigmi
# Processing Record 50 of Set 1 | san julian
# Processing Record 0 of Set 2 | farap
# Processing Record 1 of Set 2 | palikir - national government center
# Processing Record 2 of Set 2 | sabha
# Processing Record 3 of Set 2 | guerrero negro
# Processing Record 4 of Set 2 | kismayo
# Processing Record 5 of Set 2 | enewetak
# Processing Record 6 of Set 2 | port mathurin
# Processing Record 7 of Set 2 | kotma
# Processing Record 8 of Set 2 | stanley
# Processing Record 9 of Set 2 | mount gambier
# Processing Record 10 of Set 2 | edinburgh of the seven seas
# Processing Record 11 of Set 2 | sterling
# Processing Record 12 of Set 2 | rabigh
# Processing Record 13 of Set 2 | paciran
# Processing Record 14 of Set 2 | ushuaia
# Processing Record 15 of Set 2 | ostersund
# Processing Record 16 of Set 2 | san andres
# Processing Record 17 of Set 2 | fochville
# Processing Record 18 of Set 2 | mar del plata
# Processing Record 19 of Set 2 | bilibino
# Processing Record 20 of Set 2 | aioun
# Processing Record 21 of Set 2 | keflavik
# Processing Record 22 of Set 2 | swakopmund
# Processing Record 23 of Set 2 | badger
# Processing Record 24 of Set 2 | cozumel
# Processing Record 25 of Set 2 | qaqortoq
# Processing Record 26 of Set 2 | malpe
# Processing Record 27 of Set 2 | puerto ayora
# Processing Record 28 of Set 2 | wailua homesteads
# Processing Record 29 of Set 2 | kirensk
# Processing Record 30 of Set 2 | udachny
# Processing Record 31 of Set 2 | belle fourche
# Processing Record 32 of Set 2 | quang ngai
# Processing Record 33 of Set 2 | fort bragg
# Processing Record 34 of Set 2 | kirakira
# Processing Record 35 of Set 2 | kamba
# Processing Record 36 of Set 2 | ciudad constitucion
# Processing Record 37 of Set 2 | ugoofaaru
# Processing Record 38 of Set 2 | atafu village
# Processing Record 39 of Set 2 | harper
# Processing Record 40 of Set 2 | iqaluit
# Processing Record 41 of Set 2 | santa cruz
# Processing Record 42 of Set 2 | olonkinbyen
# Processing Record 43 of Set 2 | college
# Processing Record 44 of Set 2 | susuman
# Processing Record 45 of Set 2 | acarau
# Processing Record 46 of Set 2 | petrolina
# Processing Record 47 of Set 2 | umuahia
# Processing Record 48 of Set 2 | iskitim
# Processing Record 49 of Set 2 | al 'aziziyah
# Processing Record 0 of Set 3 | vilyuchinsk
# Processing Record 1 of Set 3 | pisco
# Processing Record 2 of Set 3 | petropavlovsk-kamchatsky
# Processing Record 3 of Set 3 | breckenridge
# Processing Record 4 of Set 3 | choibalsan
# Processing Record 5 of Set 3 | trongsa
# Processing Record 6 of Set 3 | rosarito
# Processing Record 7 of Set 3 | mangalia
# Processing Record 8 of Set 3 | longyearbyen
# Processing Record 9 of Set 3 | santyoku
# Processing Record 10 of Set 3 | nuuk
# Processing Record 11 of Set 3 | port elizabeth
# Processing Record 12 of Set 3 | tabriz
# Processing Record 13 of Set 3 | churapcha
# Processing Record 14 of Set 3 | isla mujeres
# Processing Record 15 of Set 3 | whitehorse
# Processing Record 16 of Set 3 | odda
# Processing Record 17 of Set 3 | avarua
# Processing Record 18 of Set 3 | longueau
# Processing Record 19 of Set 3 | amasra
# Processing Record 20 of Set 3 | albany
# Processing Record 21 of Set 3 | galle
# Processing Record 22 of Set 3 | inhambane
# Processing Record 23 of Set 3 | turpan
# Processing Record 24 of Set 3 | san patricio
# Processing Record 25 of Set 3 | kodiak
# Processing Record 26 of Set 3 | laem sing
# Processing Record 27 of Set 3 | mogadishu
# Processing Record 28 of Set 3 | as sulayyil
# Processing Record 29 of Set 3 | coahuayana de hidalgo
# Processing Record 30 of Set 3 | remire-montjoly
# Processing Record 31 of Set 3 | east ballina
# Processing Record 32 of Set 3 | greymouth
# Processing Record 33 of Set 3 | namibe
# Processing Record 34 of Set 3 | isangel
# Processing Record 35 of Set 3 | tolanaro
# Processing Record 36 of Set 3 | puerto natales
# Processing Record 37 of Set 3 | arraial do cabo
# Processing Record 38 of Set 3 | clarksville
# Processing Record 39 of Set 3 | kidal
# Processing Record 40 of Set 3 | hawaiian paradise park
# Processing Record 41 of Set 3 | hovd
# Processing Record 42 of Set 3 | ebon
# Processing Record 43 of Set 3 | taoudenni
# Processing Record 44 of Set 3 | tan-tan
# Processing Record 45 of Set 3 | quellon
# Processing Record 46 of Set 3 | lesnoy
# Processing Record 47 of Set 3 | uturoa
# Processing Record 48 of Set 3 | ubari
# Processing Record 49 of Set 3 | jilib
# Processing Record 0 of Set 4 | phan rang-thap cham
# Processing Record 1 of Set 4 | saint-joseph
# Processing Record 2 of Set 4 | margaret river
# Processing Record 3 of Set 4 | tura
# Processing Record 4 of Set 4 | geraldton
# Processing Record 5 of Set 4 | anibare
# City not found. Skipping...
# Processing Record 6 of Set 4 | brookings
# Processing Record 7 of Set 4 | petauke
# Processing Record 8 of Set 4 | kargasok
# Processing Record 9 of Set 4 | rossano stazione
# City not found. Skipping...
# Processing Record 10 of Set 4 | sinop
# Processing Record 11 of Set 4 | kerikeri
# Processing Record 12 of Set 4 | gua musang
# Processing Record 13 of Set 4 | lihue
# Processing Record 14 of Set 4 | santa terezinha
# Processing Record 15 of Set 4 | carnarvon
# Processing Record 16 of Set 4 | kapa'a
# Processing Record 17 of Set 4 | merizo village
# Processing Record 18 of Set 4 | hamilton
# Processing Record 19 of Set 4 | tambopata
# Processing Record 20 of Set 4 | babana
# Processing Record 21 of Set 4 | port alfred
# Processing Record 22 of Set 4 | sos'va
# Processing Record 23 of Set 4 | onguday
# Processing Record 24 of Set 4 | san pedro
# Processing Record 25 of Set 4 | dolores
# Processing Record 26 of Set 4 | nar'yan-mar
# Processing Record 27 of Set 4 | puerto deseado
# Processing Record 28 of Set 4 | kapuskasing
# Processing Record 29 of Set 4 | bei'an
# Processing Record 30 of Set 4 | freetown
# Processing Record 31 of Set 4 | starkville
# Processing Record 32 of Set 4 | haiku-pauwela
# Processing Record 33 of Set 4 | cobija
# Processing Record 34 of Set 4 | vingt cinq
# City not found. Skipping...
# Processing Record 35 of Set 4 | langepas
# Processing Record 36 of Set 4 | port lincoln
# Processing Record 37 of Set 4 | dubnica nad vahom
# Processing Record 38 of Set 4 | howrah
# Processing Record 39 of Set 4 | baiti
# Processing Record 40 of Set 4 | crane
# Processing Record 41 of Set 4 | yaren
# Processing Record 42 of Set 4 | touros
# Processing Record 43 of Set 4 | ar ruways
# Processing Record 44 of Set 4 | arvayheer
# Processing Record 45 of Set 4 | kyshtovka
# Processing Record 46 of Set 4 | travnik
# Processing Record 47 of Set 4 | lembar
# City not found. Skipping...
# Processing Record 48 of Set 4 | pamanukan
# Processing Record 49 of Set 4 | kulia village
# City not found. Skipping...
# Processing Record 0 of Set 5 | st. john's
# Processing Record 1 of Set 5 | kruisfontein
# Processing Record 2 of Set 5 | al kharj
# Processing Record 3 of Set 5 | tazovsky
# Processing Record 4 of Set 5 | xinpu
# Processing Record 5 of Set 5 | chui
# Processing Record 6 of Set 5 | punta arenas
# Processing Record 7 of Set 5 | staryya darohi
# Processing Record 8 of Set 5 | kazalinsk
# City not found. Skipping...
# Processing Record 9 of Set 5 | papao
# Processing Record 10 of Set 5 | tidjikja
# Processing Record 11 of Set 5 | 'ohonua
# City not found. Skipping...
# Processing Record 12 of Set 5 | constantia
# Processing Record 13 of Set 5 | akdepe
# Processing Record 14 of Set 5 | richards bay
# Processing Record 15 of Set 5 | hammerfest
# Processing Record 16 of Set 5 | colonia
# Processing Record 17 of Set 5 | klyuchi
# Processing Record 18 of Set 5 | dali
# Processing Record 19 of Set 5 | new norfolk
# Processing Record 20 of Set 5 | khorixas
# Processing Record 21 of Set 5 | webster city
# Processing Record 22 of Set 5 | cumaribo
# City not found. Skipping...
# Processing Record 23 of Set 5 | mukalla
# Processing Record 24 of Set 5 | raduzhny
# Processing Record 25 of Set 5 | kos
# Processing Record 26 of Set 5 | conde
# Processing Record 27 of Set 5 | bhimunipatnam
# Processing Record 28 of Set 5 | sacramento
# Processing Record 29 of Set 5 | guozhen
# Processing Record 30 of Set 5 | sao felix do xingu
# Processing Record 31 of Set 5 | davutlar
# Processing Record 32 of Set 5 | san isidro
# Processing Record 33 of Set 5 | kharp
# Processing Record 34 of Set 5 | tazacorte
# Processing Record 35 of Set 5 | minas de matahambre
# City not found. Skipping...
# Processing Record 36 of Set 5 | san clemente del tuyu
# Processing Record 37 of Set 5 | bahua
# Processing Record 38 of Set 5 | saldanha
# Processing Record 39 of Set 5 | afaahiti
# Processing Record 40 of Set 5 | nouadhibou
# Processing Record 41 of Set 5 | son la
# Processing Record 42 of Set 5 | sur
# Processing Record 43 of Set 5 | matoury
# Processing Record 44 of Set 5 | kailua-kona
# Processing Record 45 of Set 5 | kerbakhiar
# Processing Record 46 of Set 5 | taunggyi
# Processing Record 47 of Set 5 | tarawa
# Processing Record 48 of Set 5 | mugia
# Processing Record 49 of Set 5 | karratha
# Processing Record 0 of Set 6 | maych'ew
# Processing Record 1 of Set 6 | kerch
# Processing Record 2 of Set 6 | san antonio de pale
# Processing Record 3 of Set 6 | saudarkrokur
# Processing Record 4 of Set 6 | nikolayevsk-on-amure
# Processing Record 5 of Set 6 | aktau
# Processing Record 6 of Set 6 | swan hill
# Processing Record 7 of Set 6 | tranovaho
# City not found. Skipping...
# Processing Record 8 of Set 6 | kayangel
# Processing Record 9 of Set 6 | uliastay
# Processing Record 10 of Set 6 | yardimli
# Processing Record 11 of Set 6 | shimoda
# Processing Record 12 of Set 6 | ribeira grande
# Processing Record 13 of Set 6 | ulsteinvik
# Processing Record 14 of Set 6 | ndele
# Processing Record 15 of Set 6 | nemuro
# Processing Record 16 of Set 6 | vernon
# Processing Record 17 of Set 6 | birao
# Processing Record 18 of Set 6 | bandarbeyla
# Processing Record 19 of Set 6 | sumbawa besar
# Processing Record 20 of Set 6 | shalkar
# Processing Record 21 of Set 6 | holualoa
# Processing Record 22 of Set 6 | bonthe
# Processing Record 23 of Set 6 | west island
# Processing Record 24 of Set 6 | south hedland
# Processing Record 25 of Set 6 | san juan del sur
# Processing Record 26 of Set 6 | ola
# Processing Record 27 of Set 6 | coquimbo
# Processing Record 28 of Set 6 | zhezqazghan
# Processing Record 29 of Set 6 | soderkoping
# City not found. Skipping...
# Processing Record 30 of Set 6 | gadzhiyevo
# Processing Record 31 of Set 6 | chincholi
# Processing Record 32 of Set 6 | igarka
# Processing Record 33 of Set 6 | puerto san carlos
# City not found. Skipping...
# Processing Record 34 of Set 6 | necochea
# Processing Record 35 of Set 6 | happy valley-goose bay
# Processing Record 36 of Set 6 | gobabis
# Processing Record 37 of Set 6 | cabo san lucas
# Processing Record 38 of Set 6 | mount pearl
# Processing Record 39 of Set 6 | ko pha ngan
# Processing Record 40 of Set 6 | oranjemund
# Processing Record 41 of Set 6 | tutoia
# Processing Record 42 of Set 6 | tissemsilt
# Processing Record 43 of Set 6 | ancud
# Processing Record 44 of Set 6 | moanda
# Processing Record 45 of Set 6 | jamestown
# Processing Record 46 of Set 6 | caleta de carquin
# Processing Record 47 of Set 6 | celestun
# Processing Record 48 of Set 6 | ciudad lazaro cardenas
# Processing Record 49 of Set 6 | ciudad bolivar
# Processing Record 0 of Set 7 | itoman
# Processing Record 1 of Set 7 | dunedin
# Processing Record 2 of Set 7 | kununurra
# Processing Record 3 of Set 7 | lubang
# Processing Record 4 of Set 7 | bac lieu
# Processing Record 5 of Set 7 | piti village
# Processing Record 6 of Set 7 | cartagena del chaira
# Processing Record 7 of Set 7 | kuching
# Processing Record 8 of Set 7 | tralee
# Processing Record 9 of Set 7 | chamba
# Processing Record 10 of Set 7 | naze
# Processing Record 11 of Set 7 | rawson
# Processing Record 12 of Set 7 | fagersta
# Processing Record 13 of Set 7 | mlowo
# Processing Record 14 of Set 7 | yorkton
# Processing Record 15 of Set 7 | arroyo
# Processing Record 16 of Set 7 | antsiranana
# Processing Record 17 of Set 7 | belyy yar
# Processing Record 18 of Set 7 | flin flon
# Processing Record 19 of Set 7 | farafangana
# Processing Record 20 of Set 7 | castillos
# Processing Record 21 of Set 7 | anadyr
# Processing Record 22 of Set 7 | namtsy
# Processing Record 23 of Set 7 | ghadamis
# Processing Record 24 of Set 7 | fort st. john
# Processing Record 25 of Set 7 | wellington
# Processing Record 26 of Set 7 | san carlos de bariloche
# Processing Record 27 of Set 7 | okhotsk
# Processing Record 28 of Set 7 | porto seguro
# Processing Record 29 of Set 7 | monroe
# Processing Record 30 of Set 7 | batticaloa
# Processing Record 31 of Set 7 | barra de santo antonio
# Processing Record 32 of Set 7 | yandev
# Processing Record 33 of Set 7 | old town
# Processing Record 34 of Set 7 | kiruna
# Processing Record 35 of Set 7 | yuli
# Processing Record 36 of Set 7 | revda
# Processing Record 37 of Set 7 | rancho palos verdes
# Processing Record 38 of Set 7 | ust'-ilimsk
# Processing Record 39 of Set 7 | quibala
# Processing Record 40 of Set 7 | vila franca do campo
# Processing Record 41 of Set 7 | awjilah
# Processing Record 42 of Set 7 | island harbour
# Processing Record 43 of Set 7 | norderney
# Processing Record 44 of Set 7 | san juan
# Processing Record 45 of Set 7 | gwadar
# Processing Record 46 of Set 7 | bardai
# Processing Record 47 of Set 7 | fuling
# Processing Record 48 of Set 7 | riberalta
# Processing Record 49 of Set 7 | hadibu
# Processing Record 0 of Set 8 | lubao
# Processing Record 1 of Set 8 | zaozersk
# Processing Record 2 of Set 8 | oyem
# Processing Record 3 of Set 8 | dudinka
# Processing Record 4 of Set 8 | la passe
# Processing Record 5 of Set 8 | corredor
# Processing Record 6 of Set 8 | corbii mari
# Processing Record 7 of Set 8 | higuera de zaragoza
# Processing Record 8 of Set 8 | ocean shores
# Processing Record 9 of Set 8 | ust-nera
# Processing Record 10 of Set 8 | melekeok village
# Processing Record 11 of Set 8 | ataq
# Processing Record 12 of Set 8 | viedma
# Processing Record 13 of Set 8 | muscat
# Processing Record 14 of Set 8 | nova sintra
# Processing Record 15 of Set 8 | portland
# Processing Record 16 of Set 8 | dongfeng
# Processing Record 17 of Set 8 | arkalyk
# Processing Record 18 of Set 8 | ijuw
# City not found. Skipping...
# Processing Record 19 of Set 8 | mana
# Processing Record 20 of Set 8 | dorado
# Processing Record 21 of Set 8 | sukumo
# Processing Record 22 of Set 8 | moyale
# Processing Record 23 of Set 8 | nalerigu
# City not found. Skipping...
# Processing Record 24 of Set 8 | lakatoro
# Processing Record 25 of Set 8 | tamanrasset
# Processing Record 26 of Set 8 | novodvinsk
# Processing Record 27 of Set 8 | lagos
# Processing Record 28 of Set 8 | nova vicosa
# Processing Record 29 of Set 8 | la serena
# Processing Record 30 of Set 8 | wynyard
# Processing Record 31 of Set 8 | imbituba
# Processing Record 32 of Set 8 | derbent
# Processing Record 33 of Set 8 | gandajika
# Processing Record 34 of Set 8 | eyl
# Processing Record 35 of Set 8 | manokwari
# Processing Record 36 of Set 8 | vadso
# Processing Record 37 of Set 8 | argostolion
# Processing Record 38 of Set 8 | i-n-salah
# Processing Record 39 of Set 8 | darovskoy
# Processing Record 40 of Set 8 | el porvenir
# Processing Record 41 of Set 8 | planaltina
# Processing Record 42 of Set 8 | nicoya
# Processing Record 43 of Set 8 | ketchikan
# Processing Record 44 of Set 8 | makokou
# Processing Record 45 of Set 8 | iskateley
# Processing Record 46 of Set 8 | dong ha
# Processing Record 47 of Set 8 | thunder bay
# Processing Record 48 of Set 8 | al mawsil al jadidah
# Processing Record 49 of Set 8 | tinajo
# Processing Record 0 of Set 9 | chesapeake
# Processing Record 1 of Set 9 | mata-utu
# Processing Record 2 of Set 9 | tulun
# Processing Record 3 of Set 9 | buala
# Processing Record 4 of Set 9 | porto cristo
# Processing Record 5 of Set 9 | egilsstadir
# Processing Record 6 of Set 9 | pierre
# Processing Record 7 of Set 9 | as saffaniyah
# Processing Record 8 of Set 9 | cargados carajos
# City not found. Skipping...
# Processing Record 9 of Set 9 | didymoteicho
# Processing Record 10 of Set 9 | sitka
# Processing Record 11 of Set 9 | khenchela
# Processing Record 12 of Set 9 | altai
# Processing Record 13 of Set 9 | jose mariano jimenez
# City not found. Skipping...
# Processing Record 14 of Set 9 | watampone
# Processing Record 15 of Set 9 | fuyu
# Processing Record 16 of Set 9 | iron river
# Processing Record 17 of Set 9 | ilha de mocambique
# Processing Record 18 of Set 9 | tvoroyri
# Processing Record 19 of Set 9 | ornskoldsvik
# Processing Record 20 of Set 9 | kharan
# Processing Record 21 of Set 9 | port shepstone
# Processing Record 22 of Set 9 | selfoss
# Processing Record 23 of Set 9 | menzelinsk
# Processing Record 24 of Set 9 | smithers
# Processing Record 25 of Set 9 | sao joao da barra
# Processing Record 26 of Set 9 | codrington
# Processing Record 27 of Set 9 | ytyk-kyuyel'
# City not found. Skipping...
# Processing Record 28 of Set 9 | vinukonda
# Processing Record 29 of Set 9 | sikeston
# Processing Record 30 of Set 9 | fortuna
# Processing Record 31 of Set 9 | vilyuysk
# Processing Record 32 of Set 9 | padang
# Processing Record 33 of Set 9 | san martin
# Processing Record 34 of Set 9 | liwonde
# Processing Record 35 of Set 9 | labrador city
# Processing Record 36 of Set 9 | zhangjiakou shi xuanhua qu
# Processing Record 37 of Set 9 | carauari
# Processing Record 38 of Set 9 | moose jaw
# Processing Record 39 of Set 9 | ormara
# Processing Record 40 of Set 9 | kasongo-lunda
# Processing Record 41 of Set 9 | chenaran
# Processing Record 42 of Set 9 | mahina
# Processing Record 43 of Set 9 | cherdyn'
# Processing Record 44 of Set 9 | saint-christol-les-ales
# Processing Record 45 of Set 9 | wanlaweyn
# Processing Record 46 of Set 9 | bandar lampung
# Processing Record 47 of Set 9 | howard springs
# Processing Record 48 of Set 9 | myitkyina
# Processing Record 49 of Set 9 | mumbwa
# Processing Record 0 of Set 10 | port douglas
# Processing Record 1 of Set 10 | yuzhno-kurilsk
# Processing Record 2 of Set 10 | alvaraes
# Processing Record 3 of Set 10 | hayma'
# City not found. Skipping...
# Processing Record 4 of Set 10 | saint-denis
# Processing Record 5 of Set 10 | fuvahmulah
# City not found. Skipping...
# Processing Record 6 of Set 10 | kota belud
# Processing Record 7 of Set 10 | kavaratti
# Processing Record 8 of Set 10 | adrar
# Processing Record 9 of Set 10 | glace bay
# Processing Record 10 of Set 10 | abepura
# Processing Record 11 of Set 10 | tingo maria
# Processing Record 12 of Set 10 | puerto aysen
# Processing Record 13 of Set 10 | tromso
# Processing Record 14 of Set 10 | port hedland
# Processing Record 15 of Set 10 | boone
# Processing Record 16 of Set 10 | sinan
# Processing Record 17 of Set 10 | arbelaez
# Processing Record 18 of Set 10 | usinsk
# Processing Record 19 of Set 10 | pampa del indio
# Processing Record 20 of Set 10 | praia da vitoria
# Processing Record 21 of Set 10 | kongsvinger
# Processing Record 22 of Set 10 | antofagasta
# Processing Record 23 of Set 10 | kenai
# Processing Record 24 of Set 10 | bembereke
# Processing Record 25 of Set 10 | usogorsk
# Processing Record 26 of Set 10 | slave lake
# Processing Record 27 of Set 10 | barabai
# Processing Record 28 of Set 10 | touba
# Processing Record 29 of Set 10 | nacozari de garcia
# Processing Record 30 of Set 10 | eureka
# Processing Record 31 of Set 10 | tobruk
# Processing Record 32 of Set 10 | tucurui
# Processing Record 33 of Set 10 | ostrovskoye
# Processing Record 34 of Set 10 | jalalabad
# Processing Record 35 of Set 10 | mizque
# Processing Record 36 of Set 10 | chepo
# Processing Record 37 of Set 10 | dubnany
# Processing Record 38 of Set 10 | fisterra
# Processing Record 39 of Set 10 | jashpurnagar
# Processing Record 40 of Set 10 | al marj
# Processing Record 41 of Set 10 | minab
# Processing Record 42 of Set 10 | dryden
# Processing Record 43 of Set 10 | reggane
# Processing Record 44 of Set 10 | rovaniemi
# Processing Record 45 of Set 10 | sao simao
# Processing Record 46 of Set 10 | alotau
# City not found. Skipping...
# Processing Record 47 of Set 10 | guarapari
# Processing Record 48 of Set 10 | saint-leu
# Processing Record 49 of Set 10 | samraong
# Processing Record 0 of Set 11 | cabedelo
# Processing Record 1 of Set 11 | joal-fadiout
# Processing Record 2 of Set 11 | espargos
# City not found. Skipping...
# Processing Record 3 of Set 11 | chililabombwe
# Processing Record 4 of Set 11 | plettenberg bay
# Processing Record 5 of Set 11 | arica
# Processing Record 6 of Set 11 | mimoso do sul
# Processing Record 7 of Set 11 | markaz-e hukumat-e darweshan
# Processing Record 8 of Set 11 | ende
# Processing Record 9 of Set 11 | pangody
# Processing Record 10 of Set 11 | el calafate
# Processing Record 11 of Set 11 | taulaga
# Processing Record 12 of Set 11 | khorugh
# Processing Record 13 of Set 11 | kuala belait
# Processing Record 14 of Set 11 | vuktyl
# Processing Record 15 of Set 11 | lepsy
# Processing Record 16 of Set 11 | vila velha
# Processing Record 17 of Set 11 | polyarnyy
# Processing Record 18 of Set 11 | yartsevo
# Processing Record 19 of Set 11 | dalai
# Processing Record 20 of Set 11 | kolonia town
# Processing Record 21 of Set 11 | guiuan
# Processing Record 22 of Set 11 | anloga
# Processing Record 23 of Set 11 | anar darah
# Processing Record 24 of Set 11 | hobyo
# Processing Record 25 of Set 11 | chipinge
# Processing Record 26 of Set 11 | takoradi
# Processing Record 27 of Set 11 | kupang
# Processing Record 28 of Set 11 | kill devil hills
# Processing Record 29 of Set 11 | saint-philippe
# Processing Record 30 of Set 11 | kristiansund
# Processing Record 31 of Set 11 | dowlatabad
# Processing Record 32 of Set 11 | firuzabad
# Processing Record 33 of Set 11 | semnan
# Processing Record 34 of Set 11 | zangguy
# City not found. Skipping...
# Processing Record 35 of Set 11 | datca
# Processing Record 36 of Set 11 | belmonte
# Processing Record 37 of Set 11 | el granada
# Processing Record 38 of Set 11 | malango
# Processing Record 39 of Set 11 | grand baie
# Processing Record 40 of Set 11 | antalaha
# Processing Record 41 of Set 11 | dzuunharaa
# Processing Record 42 of Set 11 | umea
# Processing Record 43 of Set 11 | sooke
# Processing Record 44 of Set 11 | muynoq
# Processing Record 45 of Set 11 | yeppoon
# Processing Record 46 of Set 11 | tinghir
# Processing Record 47 of Set 11 | neiafu
# Processing Record 48 of Set 11 | kralendijk
# Processing Record 49 of Set 11 | little cayman
# City not found. Skipping...
# Processing Record 0 of Set 12 | mokhsogollokh
# Processing Record 1 of Set 12 | andkhoy
# Processing Record 2 of Set 12 | barretos
# Processing Record 3 of Set 12 | waddan
# Processing Record 4 of Set 12 | bata
# Processing Record 5 of Set 12 | puerto lempira
# Processing Record 6 of Set 12 | sishilichengzi
# City not found. Skipping...
# Processing Record 7 of Set 12 | tsushima
# Processing Record 8 of Set 12 | mont-dore
# Processing Record 9 of Set 12 | akureyri
# Processing Record 10 of Set 12 | pedregal
# Processing Record 11 of Set 12 | palu
# Processing Record 12 of Set 12 | campos altos
# Processing Record 13 of Set 12 | kariba
# Processing Record 14 of Set 12 | nainpur
# Processing Record 15 of Set 12 | port saint john's
# Processing Record 16 of Set 12 | lata
# Processing Record 17 of Set 12 | manistee
# Processing Record 18 of Set 12 | cannonvale
# Processing Record 19 of Set 12 | elliot lake
# Processing Record 20 of Set 12 | hingoli
# Processing Record 21 of Set 12 | urangan
# Processing Record 22 of Set 12 | amga
# Processing Record 23 of Set 12 | west bay
# Processing Record 24 of Set 12 | el rama
# Processing Record 25 of Set 12 | melfort
# Processing Record 26 of Set 12 | kingscliff
# Processing Record 27 of Set 12 | puerto baquerizo moreno
# Processing Record 28 of Set 12 | rio turbio
# City not found. Skipping...
# Processing Record 29 of Set 12 | midvagur
# Processing Record 30 of Set 12 | cascais
# Processing Record 31 of Set 12 | dalnegorsk
# Processing Record 32 of Set 12 | truth or consequences
# Processing Record 33 of Set 12 | springbok
# Processing Record 34 of Set 12 | oroqen zizhiqi
# Processing Record 35 of Set 12 | tailai
# Processing Record 36 of Set 12 | iwanai
# Processing Record 37 of Set 12 | luderitz
# Processing Record 38 of Set 12 | tabou
# Processing Record 39 of Set 12 | grand falls-windsor
# Processing Record 40 of Set 12 | manggar
# Processing Record 41 of Set 12 | peru
# Processing Record 42 of Set 12 | checker hall
# City not found. Skipping...
# Processing Record 43 of Set 12 | dikhil
# Processing Record 44 of Set 12 | puerto armuelles
# Processing Record 45 of Set 12 | chiredzi
# Processing Record 46 of Set 12 | szeged
# Processing Record 47 of Set 12 | jilin
# Processing Record 48 of Set 12 | khandyga
# Processing Record 49 of Set 12 | caiaponia
# Processing Record 0 of Set 13 | novo aripuana
# Processing Record 1 of Set 13 | fort-shevchenko
# Processing Record 2 of Set 13 | kourou
# Processing Record 3 of Set 13 | handia
# Processing Record 4 of Set 13 | comodoro rivadavia
# Processing Record 5 of Set 13 | severo-yeniseyskiy
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          578
# Lat           578
# Lng           578
# Max Temp      578
# Humidity      578
# Cloudiness    578
# Wind Speed    578
# Country       578
# Date          578
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          yellowknife  62.4560 -114.3525     57.56        44           0
# 1               hasaki  35.7333  140.8333     93.22        67          71
# 2  fale old settlement  -9.3852 -171.2468     83.64        78         100
# 3        prince rupert  54.3161 -130.3201     64.38        66          15
# 4                utrik  11.2278  169.8474     81.27        78          20
#
#    Wind Speed Country        Date
# 0       13.00      CA  1684375742
# 1        5.88      JP  1684375984
# 2       10.13      TK  1684375984
# 3        2.01      CA  1684375984
# 4       16.53      MH  1684375984

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                         City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                yellowknife  62.4560 -114.3525     57.56        44
# 1                     hasaki  35.7333  140.8333     93.22        67
# 2        fale old settlement  -9.3852 -171.2468     83.64        78
# 3              prince rupert  54.3161 -130.3201     64.38        66
# 4                      utrik  11.2278  169.8474     81.27        78
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                 0       13.00      CA  1684375742
# 1                71        5.88      JP  1684375984
# 2               100       10.13      TK  1684375984
# 3                15        2.01      CA  1684375984
# 4                20       16.53      MH  1684375984

# %% [markdown]
# # Create the Scatter Plots Requested
# Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
latitude = city_data_df['Lat']
max_temp = city_data_df['Max Temp']

plt.scatter(x=latitude, y=max_temp, color = 'lightblue', edgecolor = 'black')

# Incorporate the other graph properties
plt.title("City Max Temperature (F) vs. Latitude (2023-04-27)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# # Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
latitude = city_data_df['Lat']
humidity = city_data_df['Humidity']
plt.scatter(x=latitude, y=humidity, color = 'lightblue', edgecolor = 'black')
# Incorporate the other graph properties
plt.title("City Humidity (%) vs. Latitude (2023-04-27)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# # Latitude Vs. Coudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
latitude = city_data_df['Lat']
cloudiness = city_data_df['Cloudiness']

plt.scatter(x=latitude, y=cloudiness, color = 'lightblue', edgecolor = 'black')

# Incorporate the other graph properties
plt.title("City Cloudiness (%) vs. Latitude (2023-04-27)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# # Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed

latitude = city_data_df['Lat']
wind_speed = city_data_df['Wind Speed']

plt.scatter(x=latitude, y=wind_speed, color = 'lightblue', edgecolor = 'black')

# Incorporate the other graph properties
plt.title("City Wind Speed (%) vs. Latitude (2023-04-27)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# # Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots

def lin_reg_plot(x,y,annotate_x,annotate_y,title,xlabel,ylabel):
    
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
    plt.scatter(x, y)
    plt.plot(x,regress_values,"r-")
    plt.annotate(line_eq,(annotate_x,annotate_y),fontsize=15,color="red")
    plt.title(f"{title}")
    plt.xlabel(f"{xlabel}")
    plt.ylabel(f"{ylabel}")
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df['Lat'] >= 0]

# Display sample data
northern_hemi_df.head()

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df['Lat'] < 0]

# Display sample data
southern_hemi_df.head()

# %% [markdown]
# # Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
lin_reg_plot(northern_hemi_df['Lat'], northern_hemi_df['Max Temp'],47,75,"City Max Temperature (F) by Latitude (Northern Hemisphere)","Latitude","Max Temperature (F)")

# %%
# Linear regression on Southern Hemisphere
lin_reg_plot(southern_hemi_df['Lat'], southern_hemi_df['Max Temp'],-50,45,"City Max Temperature (F) by Latitude (Southern Hemisphere)","Latitude","Max Temperature (F)")

# %%
### Discussion about the linear relationship: YOUR RESPONSE HERE
#There is a linear relationship between Latitude and Maximum Temperature in both the Northern and Southern Hemispheres. A Latitude of 0 denotes the Earth's equator. In the Northern Hemisphere, the slope of the line of best fit is -.98, meaning that for every degree N of the equator, Max Temperature climbs almost an entire degree (F). In the Southern Hemisphere, the slope of the line of best fit is .53, meaning that for every degree S of the equator, Max Temperature climbs approximately half a degree (F). With R-Squared values of .72 and .53 respectively (N and S), the former would be considered strong and the latter: marginally strong. It's curious that these two linear models are not simply each other's mirror image. Without much speculation, it's plausible that this has to do with the Earth's axial tilt (23.5 degrees).

# %% [markdown]
# # Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
lin_reg_plot(northern_hemi_df['Lat'], northern_hemi_df['Humidity'],45,10,"City Humidity (%) by Latitude (Northern Hemisphere)","Latitude","Humidity (%)")

# %%
# Southern Hemisphere
lin_reg_plot(southern_hemi_df['Lat'], southern_hemi_df['Humidity'],-55,20,"City Humidity (%) by Latitude (Southern Hemisphere)","Latitude","Humidity (%)")

# %%
# Discussion about the linear relationship:
#There is a weak linear relationship between Latitude and Humidity in both the Northern and Southern Hemispheres. The slope of the lines of best fit are .31 and .27 respectively. Both models' R-squared values, .07 and .04, imply that latitude may be one of several factors that affect humidity, but it in it of itself does not fully explain humidity in either hemisphere.

# %% [markdown]
# # Cloudiness vs Latitude Linear Regression Plot

# %%
# Northern Hemisphere
lin_reg_plot(northern_hemi_df['Lat'], northern_hemi_df['Cloudiness'],40,50,"City Cloudiness (%) by Latitude (Northern Hemisphere)","Latitude","Cloudiness")

# %%
# Southern Hemisphere
lin_reg_plot(southern_hemi_df['Lat'], southern_hemi_df['Cloudiness'],-55,55,"City Cloudiness (%) by Latitude (Southern Hemisphere)","Latitude","Cloudiness")

# %%
#Discussion about the linear relationship: 
#There is a stronger linear relationship between Cloudiness and Latitude in the Southern Hemisphere than there is in the Northern (line slopes of .86 and .22 respectively). Interestingly, in the Northern hemisphere, it appears that the father a city is from the equator, the cloudier it is. Whereas in the Southern Hemisphere, the closer a city is to the equator the cloudier it is. However, in both cases, the R-squared value is particularly small, implying that Latitude is far from a perfect predictor of Cloudiness.

# %% [markdown]
# # Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
lin_reg_plot(northern_hemi_df['Lat'], northern_hemi_df['Wind Speed'],0,25,"City Wind Speed (m/s) by Latitude (Northern Hemisphere)","Latitude","Wind Speed (m/s)")

# %%
# Southern Hemisphere
lin_reg_plot(southern_hemi_df['Lat'], southern_hemi_df['Wind Speed'],-55,18,"City Wind Speed (m/s) by Latitude (Southern Hemisphere)","Latitude","Wind Speed (m/s)")

# %%
#Discussion about the linear relationship:
##Among the variables analyzed thus far, Latitude and Wind Speed show the weakest linear relationship with the Northern Hemisphere having close to zero relationship at all (m = .03). In the Southern Hemisphere, the data show a slight negative correlation (m = -.15), meaning that Wind Speed increases as City's move away from the equator.
