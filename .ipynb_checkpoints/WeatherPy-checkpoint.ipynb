# %%
# Dependencies and Setup
import json
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# # Generate the Cities List by Using the citipy Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 590

# %% [markdown]
# # Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?units=imperial&appid=" + weather_api_key

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | zouerate
# Processing Record 2 of Set 1 | invercargill
# Processing Record 3 of Set 1 | isangel
# Processing Record 4 of Set 1 | port elizabeth
# Processing Record 5 of Set 1 | sola
# Processing Record 6 of Set 1 | kasongo-lunda
# Processing Record 7 of Set 1 | bethel
# Processing Record 8 of Set 1 | phan rang-thap cham
# Processing Record 9 of Set 1 | plastun
# Processing Record 10 of Set 1 | port mathurin
# Processing Record 11 of Set 1 | cassilandia
# Processing Record 12 of Set 1 | waitangi
# Processing Record 13 of Set 1 | alofi
# Processing Record 14 of Set 1 | grytviken
# Processing Record 15 of Set 1 | olonkinbyen
# Processing Record 16 of Set 1 | apucarana
# Processing Record 17 of Set 1 | tiksi
# Processing Record 18 of Set 1 | faya-largeau
# Processing Record 19 of Set 1 | talara
# Processing Record 20 of Set 1 | bilibino
# Processing Record 21 of Set 1 | kodiak
# Processing Record 22 of Set 1 | constantia
# Processing Record 23 of Set 1 | bredasdorp
# Processing Record 24 of Set 1 | georgetown
# Processing Record 25 of Set 1 | blackmans bay
# Processing Record 26 of Set 1 | hasaki
# Processing Record 27 of Set 1 | adamstown
# Processing Record 28 of Set 1 | juliaca
# Processing Record 29 of Set 1 | lihue
# Processing Record 30 of Set 1 | gadzhiyevo
# Processing Record 31 of Set 1 | yellowknife
# Processing Record 32 of Set 1 | carnarvon
# Processing Record 33 of Set 1 | pereira barreto
# Processing Record 34 of Set 1 | khash
# Processing Record 35 of Set 1 | punta arenas
# Processing Record 36 of Set 1 | keflavik
# Processing Record 37 of Set 1 | nguruka
# Processing Record 38 of Set 1 | port-aux-francais
# Processing Record 39 of Set 1 | port sudan
# Processing Record 40 of Set 1 | vorkuta
# Processing Record 41 of Set 1 | mermoz boabab
# Processing Record 42 of Set 1 | edinburgh of the seven seas
# Processing Record 43 of Set 1 | cabo san lucas
# Processing Record 44 of Set 1 | weno
# Processing Record 45 of Set 1 | santa maria
# Processing Record 46 of Set 1 | ushuaia
# Processing Record 47 of Set 1 | smithers
# Processing Record 48 of Set 1 | prenzlau
# Processing Record 49 of Set 1 | westport
# Processing Record 50 of Set 1 | klyuchi
# Processing Record 0 of Set 2 | evanston
# Processing Record 1 of Set 2 | afaahiti
# Processing Record 2 of Set 2 | palikir - national government center
# Processing Record 3 of Set 2 | kashgar
# Processing Record 4 of Set 2 | tasbuget
# City not found. Skipping...
# Processing Record 5 of Set 2 | ayaguz
# City not found. Skipping...
# Processing Record 6 of Set 2 | al khafji
# Processing Record 7 of Set 2 | west island
# Processing Record 8 of Set 2 | carlinville
# Processing Record 9 of Set 2 | mar del plata
# Processing Record 10 of Set 2 | calca
# Processing Record 11 of Set 2 | dudinka
# Processing Record 12 of Set 2 | galesong
# Processing Record 13 of Set 2 | fale old settlement
# Processing Record 14 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 15 of Set 2 | mo i rana
# Processing Record 16 of Set 2 | itapirapua
# Processing Record 17 of Set 2 | katsuren-haebaru
# Processing Record 18 of Set 2 | newport
# Processing Record 19 of Set 2 | kailua-kona
# Processing Record 20 of Set 2 | nuku'alofa
# Processing Record 21 of Set 2 | iqaluit
# Processing Record 22 of Set 2 | wotho
# Processing Record 23 of Set 2 | namibe
# Processing Record 24 of Set 2 | atafu village
# Processing Record 25 of Set 2 | lasem
# Processing Record 26 of Set 2 | vila franca do campo
# Processing Record 27 of Set 2 | colonia
# Processing Record 28 of Set 2 | zuni pueblo
# Processing Record 29 of Set 2 | saipan
# Processing Record 30 of Set 2 | jamestown
# Processing Record 31 of Set 2 | novodvinsk
# Processing Record 32 of Set 2 | larreynaga
# Processing Record 33 of Set 2 | kaoma
# Processing Record 34 of Set 2 | igarka
# Processing Record 35 of Set 2 | curvelo
# Processing Record 36 of Set 2 | ketchikan
# Processing Record 37 of Set 2 | east london
# Processing Record 38 of Set 2 | lebu
# Processing Record 39 of Set 2 | isafjordur
# Processing Record 40 of Set 2 | avarua
# Processing Record 41 of Set 2 | kone
# Processing Record 42 of Set 2 | nemuro
# Processing Record 43 of Set 2 | okulovka
# Processing Record 44 of Set 2 | gongzhuling
# Processing Record 45 of Set 2 | borujen
# Processing Record 46 of Set 2 | vorgashor
# Processing Record 47 of Set 2 | hawaiian paradise park
# Processing Record 48 of Set 2 | aasiaat
# Processing Record 49 of Set 2 | puerto natales
# Processing Record 0 of Set 3 | balikpapan
# Processing Record 1 of Set 3 | thompson
# Processing Record 2 of Set 3 | tateyama
# Processing Record 3 of Set 3 | bandarbeyla
# Processing Record 4 of Set 3 | boende
# Processing Record 5 of Set 3 | qaqortoq
# Processing Record 6 of Set 3 | anadyr
# Processing Record 7 of Set 3 | sao vicente
# Processing Record 8 of Set 3 | diego de almagro
# Processing Record 9 of Set 3 | vilyuchinsk
# Processing Record 10 of Set 3 | iskateley
# Processing Record 11 of Set 3 | antsiranana
# Processing Record 12 of Set 3 | ancud
# Processing Record 13 of Set 3 | ariquemes
# Processing Record 14 of Set 3 | bikenibeu village
# Processing Record 15 of Set 3 | kuta
# Processing Record 16 of Set 3 | zima
# Processing Record 17 of Set 3 | katsuura
# Processing Record 18 of Set 3 | chiili
# City not found. Skipping...
# Processing Record 19 of Set 3 | welland
# Processing Record 20 of Set 3 | uturoa
# Processing Record 21 of Set 3 | montrose
# Processing Record 22 of Set 3 | college
# Processing Record 23 of Set 3 | mutuali
# Processing Record 24 of Set 3 | mount pearl
# Processing Record 25 of Set 3 | flying fish cove
# Processing Record 26 of Set 3 | enewetak
# Processing Record 27 of Set 3 | san buenaventura
# Processing Record 28 of Set 3 | sherbakul'
# Processing Record 29 of Set 3 | canals
# Processing Record 30 of Set 3 | yuzhno-kurilsk
# Processing Record 31 of Set 3 | vila velha
# Processing Record 32 of Set 3 | longquan
# Processing Record 33 of Set 3 | brookings
# Processing Record 34 of Set 3 | hluti
# Processing Record 35 of Set 3 | ghadamis
# Processing Record 36 of Set 3 | tura
# Processing Record 37 of Set 3 | harnosand
# Processing Record 38 of Set 3 | al bawiti
# Processing Record 39 of Set 3 | luderitz
# Processing Record 40 of Set 3 | kingscliff
# Processing Record 41 of Set 3 | knyaze-volkonskoye
# Processing Record 42 of Set 3 | naze
# Processing Record 43 of Set 3 | nadym
# Processing Record 44 of Set 3 | la libertad
# Processing Record 45 of Set 3 | vershino-darasunskiy
# Processing Record 46 of Set 3 | port macquarie
# Processing Record 47 of Set 3 | kalmunai
# Processing Record 48 of Set 3 | nanchong
# Processing Record 49 of Set 3 | turbat
# Processing Record 0 of Set 4 | riyadh
# Processing Record 1 of Set 4 | ribeira grande
# Processing Record 2 of Set 4 | barra de santo antonio
# Processing Record 3 of Set 4 | sinop
# Processing Record 4 of Set 4 | palmas
# Processing Record 5 of Set 4 | mount gambier
# Processing Record 6 of Set 4 | san jose
# Processing Record 7 of Set 4 | praia da vitoria
# Processing Record 8 of Set 4 | baiyin
# Processing Record 9 of Set 4 | margaret river
# Processing Record 10 of Set 4 | gamba
# Processing Record 11 of Set 4 | derzhavinsk
# Processing Record 12 of Set 4 | askale
# Processing Record 13 of Set 4 | benghazi
# Processing Record 14 of Set 4 | ilulissat
# Processing Record 15 of Set 4 | kapuskasing
# Processing Record 16 of Set 4 | beyneu
# Processing Record 17 of Set 4 | ravar
# Processing Record 18 of Set 4 | utrik
# Processing Record 19 of Set 4 | belmonte
# Processing Record 20 of Set 4 | haiku-pauwela
# Processing Record 21 of Set 4 | turkmenabat
# Processing Record 22 of Set 4 | la'ie
# Processing Record 23 of Set 4 | usogorsk
# Processing Record 24 of Set 4 | nuuk
# Processing Record 25 of Set 4 | wailua homesteads
# Processing Record 26 of Set 4 | las lomas
# Processing Record 27 of Set 4 | stanley
# Processing Record 28 of Set 4 | nova vicosa
# Processing Record 29 of Set 4 | maceio
# Processing Record 30 of Set 4 | mantua
# Processing Record 31 of Set 4 | ust-nera
# Processing Record 32 of Set 4 | tvoroyri
# Processing Record 33 of Set 4 | badger
# Processing Record 34 of Set 4 | mosjoen
# Processing Record 35 of Set 4 | ishigaki
# Processing Record 36 of Set 4 | petropavlovsk-kamchatsky
# Processing Record 37 of Set 4 | revda
# Processing Record 38 of Set 4 | ugoofaaru
# Processing Record 39 of Set 4 | kourou
# Processing Record 40 of Set 4 | linxia chengguanzhen
# Processing Record 41 of Set 4 | awjilah
# Processing Record 42 of Set 4 | albany
# Processing Record 43 of Set 4 | singarayakonda
# Processing Record 44 of Set 4 | richards bay
# Processing Record 45 of Set 4 | lakatoro
# Processing Record 46 of Set 4 | pineville
# Processing Record 47 of Set 4 | puerto ayora
# Processing Record 48 of Set 4 | talnakh
# Processing Record 49 of Set 4 | copala
# Processing Record 0 of Set 5 | la ronge
# Processing Record 1 of Set 5 | ladario
# Processing Record 2 of Set 5 | enkoping
# Processing Record 3 of Set 5 | fortuna
# Processing Record 4 of Set 5 | katima mulilo
# Processing Record 5 of Set 5 | port lincoln
# Processing Record 6 of Set 5 | castillos
# Processing Record 7 of Set 5 | barabai
# Processing Record 8 of Set 5 | sitka
# Processing Record 9 of Set 5 | pemangkat
# Processing Record 10 of Set 5 | sao paulo de olivenca
# Processing Record 11 of Set 5 | airuk
# Processing Record 12 of Set 5 | irati
# Processing Record 13 of Set 5 | tahoua
# Processing Record 14 of Set 5 | khandyga
# Processing Record 15 of Set 5 | maiduguri
# Processing Record 16 of Set 5 | hadibu
# Processing Record 17 of Set 5 | rio grande
# Processing Record 18 of Set 5 | santa cruz
# Processing Record 19 of Set 5 | cabedelo
# Processing Record 20 of Set 5 | vingt cinq
# City not found. Skipping...
# Processing Record 21 of Set 5 | ihosy
# Processing Record 22 of Set 5 | hermanus
# Processing Record 23 of Set 5 | corinto
# Processing Record 24 of Set 5 | trujillo
# Processing Record 25 of Set 5 | karasburg
# Processing Record 26 of Set 5 | longyearbyen
# Processing Record 27 of Set 5 | christchurch
# Processing Record 28 of Set 5 | agat village
# Processing Record 29 of Set 5 | kibaya
# Processing Record 30 of Set 5 | espargos
# City not found. Skipping...
# Processing Record 31 of Set 5 | papatowai
# Processing Record 32 of Set 5 | blacksburg
# Processing Record 33 of Set 5 | crucecita
# Processing Record 34 of Set 5 | mbanga
# Processing Record 35 of Set 5 | wellington
# Processing Record 36 of Set 5 | al bahah
# Processing Record 37 of Set 5 | novaya igirma
# Processing Record 38 of Set 5 | luena
# Processing Record 39 of Set 5 | pacasmayo
# Processing Record 40 of Set 5 | touros
# Processing Record 41 of Set 5 | pisco
# Processing Record 42 of Set 5 | hithadhoo
# Processing Record 43 of Set 5 | the pas
# Processing Record 44 of Set 5 | taltal
# Processing Record 45 of Set 5 | sao lourenco do oeste
# Processing Record 46 of Set 5 | mount darwin
# Processing Record 47 of Set 5 | lagoa
# Processing Record 48 of Set 5 | liupanshui
# City not found. Skipping...
# Processing Record 49 of Set 5 | puerto san carlos
# City not found. Skipping...
# Processing Record 0 of Set 6 | raisen
# Processing Record 1 of Set 6 | qal'ah-ye shahr
# Processing Record 2 of Set 6 | saldanha
# Processing Record 3 of Set 6 | lydenburg
# Processing Record 4 of Set 6 | coronel dorrego
# Processing Record 5 of Set 6 | sarkand
# Processing Record 6 of Set 6 | sydney mines
# Processing Record 7 of Set 6 | tofol
# Processing Record 8 of Set 6 | pionerskiy
# Processing Record 9 of Set 6 | nabire
# Processing Record 10 of Set 6 | ha tien
# Processing Record 11 of Set 6 | pokaran
# Processing Record 12 of Set 6 | san antonio del estrecho
# City not found. Skipping...
# Processing Record 13 of Set 6 | whitehorse
# Processing Record 14 of Set 6 | vangaindrano
# Processing Record 15 of Set 6 | fomboni
# Processing Record 16 of Set 6 | san felipe
# Processing Record 17 of Set 6 | ishinomaki
# Processing Record 18 of Set 6 | maasim
# Processing Record 19 of Set 6 | kurmuk
# Processing Record 20 of Set 6 | tobi village
# City not found. Skipping...
# Processing Record 21 of Set 6 | lubango
# Processing Record 22 of Set 6 | remire-montjoly
# Processing Record 23 of Set 6 | xuanzhou
# Processing Record 24 of Set 6 | korhogo
# Processing Record 25 of Set 6 | egilsstadir
# Processing Record 26 of Set 6 | toga village
# City not found. Skipping...
# Processing Record 27 of Set 6 | san patricio
# Processing Record 28 of Set 6 | key west
# Processing Record 29 of Set 6 | huangyan
# Processing Record 30 of Set 6 | oranjemund
# Processing Record 31 of Set 6 | saint croix
# Processing Record 32 of Set 6 | trail
# Processing Record 33 of Set 6 | mastic beach
# Processing Record 34 of Set 6 | el fasher
# Processing Record 35 of Set 6 | cargados carajos
# City not found. Skipping...
# Processing Record 36 of Set 6 | urengoy
# Processing Record 37 of Set 6 | zhezqazghan
# Processing Record 38 of Set 6 | ngerengere
# Processing Record 39 of Set 6 | al fuwayliq
# Processing Record 40 of Set 6 | esbly
# Processing Record 41 of Set 6 | al ghayzah
# Processing Record 42 of Set 6 | cota
# Processing Record 43 of Set 6 | koryazhma
# Processing Record 44 of Set 6 | ningyang
# Processing Record 45 of Set 6 | moree
# Processing Record 46 of Set 6 | boguchany
# Processing Record 47 of Set 6 | metlili chaamba
# Processing Record 48 of Set 6 | mana
# Processing Record 49 of Set 6 | coahuayana de hidalgo
# Processing Record 0 of Set 7 | banda aceh
# Processing Record 1 of Set 7 | la villa del rosario
# Processing Record 2 of Set 7 | howrah
# Processing Record 3 of Set 7 | gueltat zemmour
# City not found. Skipping...
# Processing Record 4 of Set 7 | damghan
# Processing Record 5 of Set 7 | sinabang
# Processing Record 6 of Set 7 | taber
# Processing Record 7 of Set 7 | alnwick
# Processing Record 8 of Set 7 | genhe
# Processing Record 9 of Set 7 | pangody
# Processing Record 10 of Set 7 | walvis bay
# Processing Record 11 of Set 7 | black river
# Processing Record 12 of Set 7 | ormara
# Processing Record 13 of Set 7 | madang
# Processing Record 14 of Set 7 | inarajan village
# Processing Record 15 of Set 7 | guarapari
# Processing Record 16 of Set 7 | san julian
# Processing Record 17 of Set 7 | mahalapye
# Processing Record 18 of Set 7 | katabu
# Processing Record 19 of Set 7 | kalevala
# Processing Record 20 of Set 7 | port alfred
# Processing Record 21 of Set 7 | saint-zotique
# Processing Record 22 of Set 7 | bitkine
# Processing Record 23 of Set 7 | kavaratti
# Processing Record 24 of Set 7 | juneau
# Processing Record 25 of Set 7 | ulladulla
# Processing Record 26 of Set 7 | boa vista
# Processing Record 27 of Set 7 | okha
# Processing Record 28 of Set 7 | lompoc
# Processing Record 29 of Set 7 | xiaoweizhai
# Processing Record 30 of Set 7 | queenstown
# Processing Record 31 of Set 7 | lata
# Processing Record 32 of Set 7 | nar'yan-mar
# Processing Record 33 of Set 7 | gemena
# Processing Record 34 of Set 7 | polyarnyy
# Processing Record 35 of Set 7 | zeribet el oued
# Processing Record 36 of Set 7 | qamdo
# Processing Record 37 of Set 7 | dunedin
# Processing Record 38 of Set 7 | bayanhongor
# Processing Record 39 of Set 7 | yarmouth
# Processing Record 40 of Set 7 | aykhal
# Processing Record 41 of Set 7 | fuvahmulah
# City not found. Skipping...
# Processing Record 42 of Set 7 | umm kaddadah
# Processing Record 43 of Set 7 | funafuti
# Processing Record 44 of Set 7 | nishinoomote
# Processing Record 45 of Set 7 | shimoda
# Processing Record 46 of Set 7 | fortaleza
# Processing Record 47 of Set 7 | mitsamiouli
# Processing Record 48 of Set 7 | huarmey
# Processing Record 49 of Set 7 | acajutla
# Processing Record 0 of Set 8 | dera bugti
# Processing Record 1 of Set 8 | naha
# Processing Record 2 of Set 8 | myeik
# Processing Record 3 of Set 8 | udachny
# Processing Record 4 of Set 8 | murun-kuren
# Processing Record 5 of Set 8 | antofagasta
# Processing Record 6 of Set 8 | warwick
# Processing Record 7 of Set 8 | aur
# Processing Record 8 of Set 8 | alvesta
# Processing Record 9 of Set 8 | las vegas
# Processing Record 10 of Set 8 | parintins
# Processing Record 11 of Set 8 | athens
# Processing Record 12 of Set 8 | mil'kovo
# Processing Record 13 of Set 8 | rongelap
# Processing Record 14 of Set 8 | bakchar
# Processing Record 15 of Set 8 | suntar
# Processing Record 16 of Set 8 | beni
# Processing Record 17 of Set 8 | kayangel
# Processing Record 18 of Set 8 | el calafate
# Processing Record 19 of Set 8 | valparaiso
# Processing Record 20 of Set 8 | palmer
# Processing Record 21 of Set 8 | thinadhoo
# Processing Record 22 of Set 8 | king
# Processing Record 23 of Set 8 | jutai
# Processing Record 24 of Set 8 | tranovaho
# City not found. Skipping...
# Processing Record 25 of Set 8 | severnoye
# Processing Record 26 of Set 8 | caconda
# Processing Record 27 of Set 8 | tadine
# Processing Record 28 of Set 8 | north manchester
# Processing Record 29 of Set 8 | nova sintra
# Processing Record 30 of Set 8 | malango
# Processing Record 31 of Set 8 | 'ohonua
# City not found. Skipping...
# Processing Record 32 of Set 8 | tazovsky
# Processing Record 33 of Set 8 | steinkjer
# Processing Record 34 of Set 8 | ts'nori
# Processing Record 35 of Set 8 | veraval
# Processing Record 36 of Set 8 | crane
# Processing Record 37 of Set 8 | hastings
# Processing Record 38 of Set 8 | usinsk
# Processing Record 39 of Set 8 | statesville
# Processing Record 40 of Set 8 | sturgis
# Processing Record 41 of Set 8 | bel ombre
# Processing Record 42 of Set 8 | ciudad bolivar
# Processing Record 43 of Set 8 | nanzhou
# Processing Record 44 of Set 8 | mount isa
# Processing Record 45 of Set 8 | korla
# Processing Record 46 of Set 8 | tempio pausania
# Processing Record 47 of Set 8 | sombor
# Processing Record 48 of Set 8 | lock haven
# Processing Record 49 of Set 8 | yagry
# City not found. Skipping...
# Processing Record 0 of Set 9 | shingu
# Processing Record 1 of Set 9 | isabela
# Processing Record 2 of Set 9 | progreso
# Processing Record 3 of Set 9 | menongue
# Processing Record 4 of Set 9 | tsiombe
# Processing Record 5 of Set 9 | al shamkhah city
# City not found. Skipping...
# Processing Record 6 of Set 9 | mek'ele
# Processing Record 7 of Set 9 | arraial do cabo
# Processing Record 8 of Set 9 | ta`u
# Processing Record 9 of Set 9 | dauphin
# Processing Record 10 of Set 9 | hovd
# Processing Record 11 of Set 9 | la passe
# Processing Record 12 of Set 9 | ilam
# Processing Record 13 of Set 9 | tazacorte
# Processing Record 14 of Set 9 | fort st. john
# Processing Record 15 of Set 9 | lorengau
# Processing Record 16 of Set 9 | morro bay
# Processing Record 17 of Set 9 | medina
# Processing Record 18 of Set 9 | kili
# Processing Record 19 of Set 9 | leh
# Processing Record 20 of Set 9 | nikolayevsk-on-amure
# Processing Record 21 of Set 9 | midvagur
# Processing Record 22 of Set 9 | mcpherson
# Processing Record 23 of Set 9 | north battleford
# Processing Record 24 of Set 9 | fort bragg
# Processing Record 25 of Set 9 | laguna
# Processing Record 26 of Set 9 | vadso
# Processing Record 27 of Set 9 | fisterra
# Processing Record 28 of Set 9 | kataragama
# City not found. Skipping...
# Processing Record 29 of Set 9 | petrolina
# Processing Record 30 of Set 9 | malyye derbety
# Processing Record 31 of Set 9 | acarau
# Processing Record 32 of Set 9 | port douglas
# Processing Record 33 of Set 9 | kyren
# Processing Record 34 of Set 9 | hayma'
# City not found. Skipping...
# Processing Record 35 of Set 9 | ahau
# City not found. Skipping...
# Processing Record 36 of Set 9 | bargara
# City not found. Skipping...
# Processing Record 37 of Set 9 | khanty-mansiysk
# Processing Record 38 of Set 9 | borogontsy
# Processing Record 39 of Set 9 | geraldton
# Processing Record 40 of Set 9 | as sulayyil
# Processing Record 41 of Set 9 | bayganin
# Processing Record 42 of Set 9 | kabansk
# Processing Record 43 of Set 9 | kosh-agach
# Processing Record 44 of Set 9 | auki
# Processing Record 45 of Set 9 | baruun-urt
# Processing Record 46 of Set 9 | sale
# Processing Record 47 of Set 9 | chui
# Processing Record 48 of Set 9 | mossel bay
# Processing Record 49 of Set 9 | maryborough
# Processing Record 0 of Set 10 | kapa'a
# Processing Record 1 of Set 10 | cockburn town
# Processing Record 2 of Set 10 | eduardo castex
# Processing Record 3 of Set 10 | black point
# Processing Record 4 of Set 10 | xiva
# Processing Record 5 of Set 10 | kangding
# Processing Record 6 of Set 10 | otjimbingwe
# Processing Record 7 of Set 10 | hinton
# Processing Record 8 of Set 10 | winnemucca
# Processing Record 9 of Set 10 | mananjary
# Processing Record 10 of Set 10 | akureyri
# Processing Record 11 of Set 10 | clifton
# Processing Record 12 of Set 10 | porto novo
# Processing Record 13 of Set 10 | belle fourche
# Processing Record 14 of Set 10 | harrisburg
# Processing Record 15 of Set 10 | tsetserleg
# Processing Record 16 of Set 10 | mirny
# Processing Record 17 of Set 10 | necochea
# Processing Record 18 of Set 10 | ouezzane
# Processing Record 19 of Set 10 | wickenburg
# Processing Record 20 of Set 10 | newman
# Processing Record 21 of Set 10 | happy valley-goose bay
# Processing Record 22 of Set 10 | ratnagiri
# Processing Record 23 of Set 10 | chegdomyn
# Processing Record 24 of Set 10 | kabinda
# Processing Record 25 of Set 10 | zonguldak
# Processing Record 26 of Set 10 | bismil
# Processing Record 27 of Set 10 | lucapa
# Processing Record 28 of Set 10 | turuntayevo
# Processing Record 29 of Set 10 | kuloy
# Processing Record 30 of Set 10 | fiambala
# Processing Record 31 of Set 10 | nantucket
# Processing Record 32 of Set 10 | altai
# Processing Record 33 of Set 10 | taoudenni
# Processing Record 34 of Set 10 | eastham
# Processing Record 35 of Set 10 | gaiman
# Processing Record 36 of Set 10 | wanning
# Processing Record 37 of Set 10 | longboat key
# Processing Record 38 of Set 10 | luchegorsk
# Processing Record 39 of Set 10 | puerto leguizamo
# Processing Record 40 of Set 10 | dongsheng
# Processing Record 41 of Set 10 | maumere
# Processing Record 42 of Set 10 | saint-pierre
# Processing Record 43 of Set 10 | xinyuan
# Processing Record 44 of Set 10 | lobujya
# Processing Record 45 of Set 10 | sao jose da coroa grande
# Processing Record 46 of Set 10 | dondo
# Processing Record 47 of Set 10 | hirara
# Processing Record 48 of Set 10 | pavlodar
# Processing Record 49 of Set 10 | cannonvale
# Processing Record 0 of Set 11 | howard springs
# Processing Record 1 of Set 11 | balkanabat
# Processing Record 2 of Set 11 | dum duma
# Processing Record 3 of Set 11 | amga
# Processing Record 4 of Set 11 | st. john's
# Processing Record 5 of Set 11 | morehead city
# Processing Record 6 of Set 11 | monte argentario
# Processing Record 7 of Set 11 | mtambile
# Processing Record 8 of Set 11 | azul
# Processing Record 9 of Set 11 | pajacuaran
# Processing Record 10 of Set 11 | young
# Processing Record 11 of Set 11 | tralee
# Processing Record 12 of Set 11 | lenger
# Processing Record 13 of Set 11 | kolonia town
# Processing Record 14 of Set 11 | gorontalo
# Processing Record 15 of Set 11 | den burg
# Processing Record 16 of Set 11 | argo
# Processing Record 17 of Set 11 | puerto baquerizo moreno
# Processing Record 18 of Set 11 | lijiang
# Processing Record 19 of Set 11 | bereznik
# Processing Record 20 of Set 11 | ulaangom
# Processing Record 21 of Set 11 | aleksandrovsk-sakhalinskiy
# Processing Record 22 of Set 11 | juegang
# Processing Record 23 of Set 11 | iquitos
# Processing Record 24 of Set 11 | yakeshi
# Processing Record 25 of Set 11 | lautoka
# Processing Record 26 of Set 11 | sao joao da barra
# Processing Record 27 of Set 11 | susuman
# Processing Record 28 of Set 11 | la foa
# Processing Record 29 of Set 11 | chumphon
# Processing Record 30 of Set 11 | sokoni
# Processing Record 31 of Set 11 | chonchi
# Processing Record 32 of Set 11 | dhidhdhoo
# Processing Record 33 of Set 11 | bardai
# Processing Record 34 of Set 11 | isle of lewis
# City not found. Skipping...
# Processing Record 35 of Set 11 | belyy yar
# Processing Record 36 of Set 11 | luwuk
# Processing Record 37 of Set 11 | kuusamo
# Processing Record 38 of Set 11 | shangqiu
# Processing Record 39 of Set 11 | abalak
# Processing Record 40 of Set 11 | constitucion
# Processing Record 41 of Set 11 | hami
# Processing Record 42 of Set 11 | eyl
# Processing Record 43 of Set 11 | arno
# Processing Record 44 of Set 11 | hamilton
# Processing Record 45 of Set 11 | bratislava
# Processing Record 46 of Set 11 | mercedes
# Processing Record 47 of Set 11 | am timan
# Processing Record 48 of Set 11 | pontian kechil
# Processing Record 49 of Set 11 | tripoli
# Processing Record 0 of Set 12 | muroto-misakicho
# Processing Record 1 of Set 12 | visakhapatnam
# Processing Record 2 of Set 12 | mukah
# City not found. Skipping...
# Processing Record 3 of Set 12 | buka
# Processing Record 4 of Set 12 | moanda
# Processing Record 5 of Set 12 | antonio enes
# Processing Record 6 of Set 12 | praia
# Processing Record 7 of Set 12 | chibougamau
# Processing Record 8 of Set 12 | cattolica
# Processing Record 9 of Set 12 | san antonio de pale
# Processing Record 10 of Set 12 | camayenne
# Processing Record 11 of Set 12 | punta del este
# Processing Record 12 of Set 12 | yuxi
# Processing Record 13 of Set 12 | kununurra
# Processing Record 14 of Set 12 | beira
# Processing Record 15 of Set 12 | maxixe
# Processing Record 16 of Set 12 | naama
# Processing Record 17 of Set 12 | preobrazheniye
# Processing Record 18 of Set 12 | rikaze
# Processing Record 19 of Set 12 | barah
# Processing Record 20 of Set 12 | janakpur
# Processing Record 21 of Set 12 | benjamin aceval
# Processing Record 22 of Set 12 | west bay
# Processing Record 23 of Set 12 | lamu
# Processing Record 24 of Set 12 | ponnani
# Processing Record 25 of Set 12 | sidi akkacha
# Processing Record 26 of Set 12 | conduaga
# Processing Record 27 of Set 12 | san jose village
# City not found. Skipping...
# Processing Record 28 of Set 12 | angaur state
# Processing Record 29 of Set 12 | vilyuysk
# Processing Record 30 of Set 12 | nalut
# Processing Record 31 of Set 12 | devrek
# Processing Record 32 of Set 12 | emmett
# Processing Record 33 of Set 12 | northam
# Processing Record 34 of Set 12 | codrington
# Processing Record 35 of Set 12 | stephenville
# Processing Record 36 of Set 12 | bordighera
# Processing Record 37 of Set 12 | pandan
# Processing Record 38 of Set 12 | moyale
# Processing Record 39 of Set 12 | uruguaiana
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          565
# Lat           565
# Lng           565
# Max Temp      565
# Humidity      565
# Cloudiness    565
# Wind Speed    565
# Country       565
# Date          565
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        zouerate  22.7187  -12.4521     86.38        11          17
# 1    invercargill -46.4000  168.3500     42.49        82          70
# 2         isangel -19.5500  169.2667     73.96        73          99
# 3  port elizabeth -33.9180   25.5701     60.31        77           0
# 4            sola -13.8833  167.5500     80.65        83          94
#
#    Wind Speed Country        Date
# 0       12.24      MR  1684603824
# 1        2.06      NZ  1684603824
# 2       10.58      VU  1684603485
# 3        5.75      ZA  1684603825
# 4       12.73      VU  1684603826

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0              zouerate  22.7187  -12.4521     86.38        11          17
# 1          invercargill -46.4000  168.3500     42.49        82          70
# 2               isangel -19.5500  169.2667     73.96        73          99
# 3        port elizabeth -33.9180   25.5701     60.31        77           0
# 4                  sola -13.8833  167.5500     80.65        83          94
#
#          Wind Speed Country        Date
# City_ID
# 0             12.24      MR  1684603824
# 1              2.06      NZ  1684603824
# 2             10.58      VU  1684603485
# 3              5.75      ZA  1684603825
# 4             12.73      VU  1684603826

# %% [markdown]
# # Create the Scatter Plots Requested
# Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
latitude = city_data_df['Lat']
max_temp = city_data_df['Max Temp']

plt.scatter(x=latitude, y=max_temp, color = 'lightblue', edgecolor = 'black')

# Incorporate the other graph properties
plt.title("City Max Temperature (F) vs. Latitude (2023-04-27)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# # Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
latitude = city_data_df['Lat']
humidity = city_data_df['Humidity']
plt.scatter(x=latitude, y=humidity, color = 'lightblue', edgecolor = 'black')
# Incorporate the other graph properties
plt.title("City Humidity (%) vs. Latitude (2023-04-27)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# # Latitude Vs. Coudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
latitude = city_data_df['Lat']
cloudiness = city_data_df['Cloudiness']

plt.scatter(x=latitude, y=cloudiness, color = 'lightblue', edgecolor = 'black')

# Incorporate the other graph properties
plt.title("City Cloudiness (%) vs. Latitude (2023-04-27)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# # Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed

latitude = city_data_df['Lat']
wind_speed = city_data_df['Wind Speed']

plt.scatter(x=latitude, y=wind_speed, color = 'lightblue', edgecolor = 'black')

# Incorporate the other graph properties
plt.title("City Wind Speed (%) vs. Latitude (2023-04-27)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# # Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots

def lin_reg_plot(x,y,annotate_x,annotate_y,title,xlabel,ylabel):
    
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
    plt.scatter(x, y)
    plt.plot(x,regress_values,"r-")
    plt.annotate(line_eq,(annotate_x,annotate_y),fontsize=15,color="red")
    plt.title(f"{title}")
    plt.xlabel(f"{xlabel}")
    plt.ylabel(f"{ylabel}")
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df['Lat'] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                         City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                   zouerate  22.7187  -12.4521     86.38        11
# 6                     bethel  41.3712  -73.4140     63.64        89
# 7        phan rang-thap cham  11.5667  108.9833     80.60        89
# 8                    plastun  44.7561  136.2939     43.00        98
# 14               olonkinbyen  70.9221   -8.7187     35.71        85
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                17       12.24      MR  1684603824
# 6               100        5.75      US  1684603826
# 7                98        4.97      VN  1684603827
# 8               100        6.06      RU  1684603827
# 14               56       20.96      SJ  1684603531

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df['Lat'] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1          invercargill -46.4000  168.3500     42.49        82          70
# 2               isangel -19.5500  169.2667     73.96        73          99
# 3        port elizabeth -33.9180   25.5701     60.31        77           0
# 4                  sola -13.8833  167.5500     80.65        83          94
# 5         kasongo-lunda  -6.4667   16.8167     74.95        90          96
#
#          Wind Speed Country        Date
# City_ID
# 1              2.06      NZ  1684603824
# 2             10.58      VU  1684603485
# 3              5.75      ZA  1684603825
# 4             12.73      VU  1684603826
# 5              1.74      CD  1684603826

# %% [markdown]
# # Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
lin_reg_plot(northern_hemi_df['Lat'], northern_hemi_df['Max Temp'],47,75,"City Max Temperature (F) by Latitude (Northern Hemisphere)","Latitude","Max Temperature (F)")

# %%
# Linear regression on Southern Hemisphere
lin_reg_plot(southern_hemi_df['Lat'], southern_hemi_df['Max Temp'],-50,45,"City Max Temperature (F) by Latitude (Southern Hemisphere)","Latitude","Max Temperature (F)")

# %%
### Discussion about the linear relationship: YOUR RESPONSE HERE
#There is a linear relationship between Latitude and Maximum Temperature in both the Northern and Southern Hemispheres. A Latitude of 0 denotes the Earth's equator. In the Northern Hemisphere, the slope of the line of best fit is -.98, meaning that for every degree N of the equator, Max Temperature climbs almost an entire degree (F). In the Southern Hemisphere, the slope of the line of best fit is .53, meaning that for every degree S of the equator, Max Temperature climbs approximately half a degree (F). With R-Squared values of .72 and .53 respectively (N and S), the former would be considered strong and the latter: marginally strong. It's curious that these two linear models are not simply each other's mirror image. Without much speculation, it's plausible that this has to do with the Earth's axial tilt (23.5 degrees).

# %% [markdown]
# # Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
lin_reg_plot(northern_hemi_df['Lat'], northern_hemi_df['Humidity'],45,10,"City Humidity (%) by Latitude (Northern Hemisphere)","Latitude","Humidity (%)")

# %%
# Southern Hemisphere
lin_reg_plot(southern_hemi_df['Lat'], southern_hemi_df['Humidity'],-55,20,"City Humidity (%) by Latitude (Southern Hemisphere)","Latitude","Humidity (%)")

# %%
# Discussion about the linear relationship:
#There is a weak linear relationship between Latitude and Humidity in both the Northern and Southern Hemispheres. The slope of the lines of best fit are .31 and .27 respectively. Both models' R-squared values, .07 and .04, imply that latitude may be one of several factors that affect humidity, but it in it of itself does not fully explain humidity in either hemisphere.

# %% [markdown]
# # Cloudiness vs Latitude Linear Regression Plot

# %%
# Northern Hemisphere
lin_reg_plot(northern_hemi_df['Lat'], northern_hemi_df['Cloudiness'],40,50,"City Cloudiness (%) by Latitude (Northern Hemisphere)","Latitude","Cloudiness")

# %%
# Southern Hemisphere
lin_reg_plot(southern_hemi_df['Lat'], southern_hemi_df['Cloudiness'],-55,55,"City Cloudiness (%) by Latitude (Southern Hemisphere)","Latitude","Cloudiness")

# %%
#Discussion about the linear relationship: 
#There is a stronger linear relationship between Cloudiness and Latitude in the Southern Hemisphere than there is in the Northern (line slopes of .86 and .22 respectively). Interestingly, in the Northern hemisphere, it appears that the father a city is from the equator, the cloudier it is. Whereas in the Southern Hemisphere, the closer a city is to the equator the cloudier it is. However, in both cases, the R-squared value is particularly small, implying that Latitude is far from a perfect predictor of Cloudiness.

# %% [markdown]
# # Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
lin_reg_plot(northern_hemi_df['Lat'], northern_hemi_df['Wind Speed'],0,25,"City Wind Speed (m/s) by Latitude (Northern Hemisphere)","Latitude","Wind Speed (m/s)")

# %%
# Southern Hemisphere
lin_reg_plot(southern_hemi_df['Lat'], southern_hemi_df['Wind Speed'],-55,18,"City Wind Speed (m/s) by Latitude (Southern Hemisphere)","Latitude","Wind Speed (m/s)")

# %%
#Discussion about the linear relationship:
##Among the variables analyzed thus far, Latitude and Wind Speed show the weakest linear relationship with the Northern Hemisphere having close to zero relationship at all (m = .03). In the Southern Hemisphere, the data show a slight negative correlation (m = -.15), meaning that Wind Speed increases as City's move away from the equator.
